# %% [markdown]
# <a href="https://colab.research.google.com/github/nandanilsss/PMB24/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dataset = '/content/Klasifikasi Tingkat Kemiskinan di Indonesia.xlsx'

data = pd.read_excel(dataset)

data
# Out:
#     Provinsi       Kab/Kota  \
# 0       ACEH       Simeulue
# 1       ACEH   Aceh Singkil
# 2       ACEH   Aceh Selatan
# 3       ACEH  Aceh Tenggara
# 4       ACEH     Aceh Timur
# ..       ...            ...
# 509    PAPUA         Puncak
# 510    PAPUA        Dogiyai
# 511    PAPUA     Intan Jaya
# 512    PAPUA         Deiyai
# 513    PAPUA  Kota Jayapura
#
#     Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)  \
# 0                                                18.98
# 1                                                20.36
# 2                                                13.18
# 3                                                13.41
# 4                                                14.45
# ..                                                 ...
# 509                                              36.26
# 510                                              28.81
# 511                                              41.66
# ...

# %%
data.head()
# Out:
#   Provinsi       Kab/Kota  \
# 0     ACEH       Simeulue
# 1     ACEH   Aceh Singkil
# 2     ACEH   Aceh Selatan
# 3     ACEH  Aceh Tenggara
# 4     ACEH     Aceh Timur
#
#   Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)  \
# 0                                              18.98
# 1                                              20.36
# 2                                              13.18
# 3                                              13.41
# 4                                              14.45
#
#   Rata-rata Lama Sekolah Penduduk 15+ (Tahun)  \
# 0                                        9.48
# 1                                        8.68
# 2                                        8.88
# 3                                        9.67
# 4                                        8.21
#
#    Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)  \
# 0                                               7148
# 1                                               8776
# ...

# %%
print(data.dtypes)
# Out:
# Provinsi                                                                 object
# Kab/Kota                                                                 object
# Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)          object
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)                              object
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)              int64
# Indeks Pembangunan Manusia                                              float64
# Umur Harapan Hidup (Tahun)                                              float64
# Persentase rumah tangga yang memiliki akses terhadap sanitasi layak     float64
# Persentase rumah tangga yang memiliki akses terhadap air minum layak    float64
# Tingkat Pengangguran Terbuka                                            float64
# Tingkat Partisipasi Angkatan Kerja                                      float64
# PDRB atas Dasar Harga Konstan menurut Pengeluaran (Rupiah)                int64
# ...

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#     Provinsi       Kab/Kota  \
# 0       ACEH       Simeulue
# 1       ACEH   Aceh Singkil
# 2       ACEH   Aceh Selatan
# 3       ACEH  Aceh Tenggara
# 4       ACEH     Aceh Timur
# ..       ...            ...
# 509    PAPUA         Puncak
# 510    PAPUA        Dogiyai
# 511    PAPUA     Intan Jaya
# 512    PAPUA         Deiyai
# 513    PAPUA  Kota Jayapura
#
#     Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)  \
# 0                                                18.98
# 1                                                20.36
# 2                                                13.18
# 3                                                13.41
# 4                                                14.45
# ..                                                 ...
# 509                                              36.26
# 510                                              28.81
# 511                                              41.66
# ...

# %%
data.describe()
# Out:
#        Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)  \
# count                                         514.000000
# mean                                        10324.787938
# std                                          2717.144186
# min                                          3976.000000
# 25%                                          8574.000000
# 50%                                         10196.500000
# 75%                                         11719.000000
# max                                         23888.000000
#
#        Indeks Pembangunan Manusia  Umur Harapan Hidup (Tahun)  \
# count                  514.000000                  514.000000
# mean                    69.926770                   69.656809
# std                      6.497033                    3.447464
# min                     32.840000                   55.430000
# 25%                     66.642500                   67.387500
# 50%                     69.610000                   69.975000
# ...

# %%
data.loc[:,"Indeks Pembangunan Manusia":].corr()
# Out:
#                                                     Indeks Pembangunan Manusia  \
# Indeks Pembangunan Manusia                                            1.000000
# Umur Harapan Hidup (Tahun)                                            0.707084
# Persentase rumah tangga yang memiliki akses ter...                    0.696754
# Persentase rumah tangga yang memiliki akses ter...                    0.549992
# Tingkat Pengangguran Terbuka                                          0.578867
# Tingkat Partisipasi Angkatan Kerja                                   -0.513052
# PDRB atas Dasar Harga Konstan menurut Pengeluar...                    0.371952
# Klasifikasi Kemiskinan                                               -0.535125
#
#                                                     Umur Harapan Hidup (Tahun)  \
# Indeks Pembangunan Manusia                                            0.707084
# Umur Harapan Hidup (Tahun)                                            1.000000
# ...

# %%
# @title Umur Harapan Hidup (Tahun) vs Indeks Pembangunan Manusia

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Umur Harapan Hidup (Tahun)', y='Indeks Pembangunan Manusia', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-1833b776-37b6-434f-ad91-7a06b9c8b495" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1833b776-37b6-434f-ad91-7a06b9c8b495">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Klasifikasi Kemiskinan"
# Out:
# ...
# ref                                                 title                                        size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------  -------------------------------------------  ----  -------------------  -------------  ---------  ---------------
# ermila/klasifikasi-tingkat-kemiskinan-di-indonesia  Klasifikasi Tingkat Kemiskinan di Indonesia  19KB  2023-12-23 04:35:16            301          9  0.4117647
# ermila/klasifikasi-kemiskinan                       Klasifikasi Kemiskinan                       10KB  2024-01-07 06:38:30             45          0  0.23529412

# %%
# !kaggle datasets download ermila/klasifikasi-kemiskinan
# Out:
# ...
#   0% 0.00/9.59k [00:00<?, ?B/s]
# 100% 9.59k/9.59k [00:00<00:00, 16.3MB/s]

# %%
# !unzip /content/klasifikasi-kemiskinan.zip
# Out:
# Archive:  /content/klasifikasi-kemiskinan.zip
#   inflating: Klasifikasi Tingkat Kemiskinan di Indonesia..csv

# %%
pd.read_csv('Klasifikasi Tingkat Kemiskinan di Indonesia..csv')
# Out:
#                                           Provinsi;Kab/Kota;Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen);Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun);Indeks Pembangunan Manusia;Tingkat Pengangguran Terbuka;Klasifikasi Kemiskinan
# ACEH;Simeulue;18       98;7148;66   41;5                                                71;0
# ACEH;Aceh Singkil;20   36;8776;69   22;8                                                36;1
# ACEH;Aceh Selatan;13   18;8180;67   44;6                                                46;0
# ACEH;Aceh Tenggara;13  41;8030;69   44;6                                                43;0
# ACEH;Aceh Timur;14     45;8577;67   83;7                                                13;0
# ...                                                                                      ...
# PAPUA;Puncak;36        26;5412;43   17;0                                                94;1
# ...
